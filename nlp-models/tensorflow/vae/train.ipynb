# %% [markdown]
# Author: [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="vae.png" width="300">

# %%
from modified import ModifiedBasicDecoder, ModifiedBeamSearchDecoder

import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'word_dropout_rate': 0.8,
    'embed_dims': 128,
    'rnn_size': 128,
    'latent_size': 16,
    'beam_width': 5,
    'num_sampled': 1000,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 30,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}
    
    PARAMS['vocab_size'] = len(PARAMS['word2idx'])

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=None, index_from=index_from)
    return (X_train, X_test)


def word_dropout(x):
    is_dropped = np.random.binomial(1, PARAMS['word_dropout_rate'], x.shape)
    fn = np.vectorize(lambda x, k: PARAMS['word2idx']['<unk>'] if (
        k and (x not in range(4))) else x)
    return fn(x, is_dropped)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = word_dropout(X)
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def reparam_trick(z_mean, z_logvar):
    gaussian = tf.truncated_normal(tf.shape(z_logvar))
    z = z_mean + tf.exp(0.5 * z_logvar) * gaussian
    return z


def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))


def kl_loss_fn(mean, gamma):
    return 0.5 * tf.reduce_sum(
        tf.exp(gamma) + tf.square(mean) - 1 - gamma) / tf.to_float(tf.shape(mean)[0])

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())


def forward(inputs, labels, reuse, is_training):
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder', reuse=reuse):
        embedding = tf.get_variable('lookup_table', [len(PARAMS['word2idx']), PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_logvar = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    z = reparam_trick(z_mean, z_logvar)
        
    with tf.variable_scope('Decoder', reuse=reuse):
        init_state = tf.layers.dense(z, PARAMS['rnn_size'], tf.nn.elu)
        output_proj = tf.layers.Dense(len(PARAMS['word2idx']), _scope='decoder/output_proj')
        dec_cell = rnn_cell()
        
        if is_training:
            dec_seq_len = tf.count_nonzero(labels['dec_out'], 1, dtype=tf.int32)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = tf.nn.embedding_lookup(embedding, labels['dec_inp']),
                sequence_length = dec_seq_len)
            decoder = ModifiedBasicDecoder(
                cell = dec_cell,
                helper = helper,
                initial_state = init_state,
                concat_z = z)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            rnn_output = decoder_output.rnn_output
            return rnn_output, output_proj(rnn_output), (z_mean, z_logvar)
        else:
            decoder = ModifiedBeamSearchDecoder(
                cell = dec_cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([PARAMS['word2idx']['<start>']], tf.int32),
                                       [batch_sz]),
                end_token = PARAMS['word2idx']['<end>'],
                initial_state = tf.contrib.seq2seq.tile_batch(init_state, PARAMS['beam_width']),
                beam_width = PARAMS['beam_width'],
                output_layer = output_proj,
                concat_z = tf.tile(tf.expand_dims(z, 1), [1, PARAMS['beam_width'], 1]))
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder)
            return decoder_output.predicted_ids[:, :, 0]

# %%
def model_fn(features, labels, mode, params):
    if labels is None:
        labels = {'dec_out': tf.placeholder(tf.int32, [None, None]),
                  'dec_inp': tf.placeholder(tf.int32, [None, None])}
    
    rnn_output, logits, (z_mean, z_logvar) = forward(
        features, labels, reuse=False, is_training=True)
    
    pred_ids = forward(features, labels, reuse=True, is_training=False)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=pred_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_global_step()
        
        with tf.variable_scope('Decoder/decoder/output_proj', reuse=True):
            _weights = tf.transpose(tf.get_variable('kernel'))
            _biases = tf.get_variable('bias')
        
        mask = tf.reshape(tf.to_float(tf.sign(labels['dec_out'])), [-1])
        
        nll_loss = tf.reduce_sum(mask * tf.nn.sampled_softmax_loss(
            weights = _weights,
            biases = _biases,
            labels = tf.reshape(labels['dec_out'], [-1, 1]),
            inputs = tf.reshape(rnn_output, [-1, PARAMS['rnn_size']]),
            num_sampled = PARAMS['num_sampled'],
            num_classes = PARAMS['vocab_size'],
        )) / tf.to_float(tf.shape(features)[0])
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = kl_loss_fn(z_mean, z_logvar)
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(
            clip_grads(loss_op),
            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))

    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1176dc6d8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x1176d0e18>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:loss = 155.76213, step = 1
# INFO:tensorflow:nll_loss = 155.76213, kl_w = 0.006692851, kl_loss = 4.7538542e-05
# INFO:tensorflow:global_step/sec: 3.00757
# INFO:tensorflow:loss = 90.91933, step = 101 (33.251 sec)
# INFO:tensorflow:nll_loss = 89.94884, kl_w = 0.007897083, kl_loss = 122.89254 (33.251 sec)
# INFO:tensorflow:global_step/sec: 2.96452
# INFO:tensorflow:loss = 83.37971, step = 201 (33.732 sec)
# INFO:tensorflow:nll_loss = 82.797134, kl_w = 0.009315956, kl_loss = 62.535202 (33.732 sec)
# INFO:tensorflow:global_step/sec: 2.94242
# INFO:tensorflow:loss = 81.70635, step = 301 (33.986 sec)
# INFO:tensorflow:nll_loss = 81.18971, kl_w = 0.010986943, kl_loss = 47.0228 (33.986 sec)
# INFO:tensorflow:global_step/sec: 3.04917
# INFO:tensorflow:loss = 84.94522, step = 401 (32.797 sec)
# INFO:tensorflow:nll_loss = 84.580124, kl_w = 0.012953726, kl_loss = 28.184586 (32.798 sec)
# INFO:tensorflow:global_step/sec: 3.04085
# INFO:tensorflow:loss = 87.19674, step = 501 (32.884 sec)
# INFO:tensorflow:nll_loss = 86.862625, kl_w = 0.015267149, kl_loss = 21.884277 (32.884 sec)
# INFO:tensorflow:global_step/sec: 3.10142
# INFO:tensorflow:loss = 81.897125, step = 601 (32.244 sec)
# INFO:tensorflow:nll_loss = 81.59355, kl_w = 0.01798621, kl_loss = 16.87809 (32.245 sec)
# INFO:tensorflow:global_step/sec: 2.90329
# INFO:tensorflow:loss = 83.90192, step = 701 (34.442 sec)
# INFO:tensorflow:nll_loss = 83.59039, kl_w = 0.021179108, kl_loss = 14.709024 (34.442 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:Loss for final step: 80.2834.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i this this this this this this this this the the the the the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: i this this this this this this this the the the the the the <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:loss =
# INFO:tensorflow:nll_loss = 60.217632, kl_w = 0.9995608, kl_loss = 9.102273 (30.852 sec)
# INFO:tensorflow:global_step/sec: 3.24937
# INFO:tensorflow:loss = 66.379364, step = 7739 (30.775 sec)
# INFO:tensorflow:nll_loss = 56.941906, kl_w = 0.9996282, kl_loss = 9.440969 (30.775 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:Loss for final step: 62.261124.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie i've ever seen it was one of the worst movie <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time to watch this movie is not a <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7821 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:loss = 62.9693, step = 7821
# INFO:tensorflow:nll_loss = 53.121017, kl_w = 0.99967563, kl_loss = 9.851476
# INFO:tensorflow:global_step/sec: 3.1237
# INFO:tensorflow:loss = 63.64765, step = 7921 (32.014 sec)
# INFO:tensorflow:nll_loss = 53.879845, kl_w = 0.9997254, kl_loss = 9.77049 (32.014 sec)
# INFO:tensorflow:global_step/sec: 3.20104
# INFO:tensorflow:loss = 66.24252, step = 8021 (31.240 sec)
# INFO:tensorflow:nll_loss = 56.718422, kl_w = 0.9997676, kl_loss = 9.526318 (31.240 sec)
# INFO:tensorflow:global_step/sec: 3.08435
# INFO:tensorflow:loss = 64.87941, step = 8121 (32.423 sec)
# INFO:tensorflow:nll_loss = 55.436234, kl_w = 0.99980325, kl_loss = 9.445039 (32.423 sec)
# INFO:tensorflow:global_step/sec: 2.46489
# INFO:tensorflow:loss = 71.05597, step = 8221 (40.569 sec)
# INFO:tensorflow:nll_loss = 61.902, kl_w = 0.99983346, kl_loss = 9.155493 (40.568 sec)
# INFO:tensorflow:global_step/sec: 2.56442
# INFO:tensorflow:loss = 68.87114, step = 8321 (38.995 sec)
# INFO:tensorflow:nll_loss = 59.851036, kl_w = 0.999859, kl_loss = 9.021379 (38.995 sec)
# INFO:tensorflow:global_step/sec: 2.93611
# INFO:tensorflow:loss = 69.11822, step = 8421 (34.059 sec)
# INFO:tensorflow:nll_loss = 59.876892, kl_w = 0.9998807, kl_loss = 9.242426 (34.059 sec)
# INFO:tensorflow:global_step/sec: 3.29432
# INFO:tensorflow:loss = 68.36365, step = 8521 (30.355 sec)
# INFO:tensorflow:nll_loss = 59.246956, kl_w = 0.9998989, kl_loss = 9.117611 (30.356 sec)
# INFO:tensorflow:Saving checkpoints for 8602 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:Loss for final step: 67.628426.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-8602
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think the movie i would have seen it was a lot of the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time don't waste your time to this movie <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-8602
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8603 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:loss = 65.06161, step = 8603
# INFO:tensorflow:nll_loss = 55.66998, kl_w = 0.9999119, kl_loss = 9.392459
# INFO:tensorflow:global_step/sec: 3.09278
# INFO:tensorflow:loss = 64.00311, step = 8703 (32.335 sec)
# INFO:tensorflow:nll_loss = 53.864952, kl_w = 0.9999254, kl_loss = 10.13892 (32.334 sec)
# INFO:tensorflow:global_step/sec: 3.08577
# INFO:tensorflow:loss = 65.06147, step = 8803 (32.407 sec)
# INFO:tensorflow:nll_loss = 55.2127, kl_w = 0.9999368, kl_loss = 9.849396 (32.407 sec)
# INFO:tensorflow:global_step/sec: 3.20737
# INFO:tensorflow:loss = 67.58996, step = 8903 (31.178 sec)
# INFO:tensorflow:nll_loss = 58.518723, kl_w = 0.9999466, kl_loss = 9.071721 (31.178 sec)
# INFO:tensorflow:global_step/sec: 3.24305
# INFO:tensorflow:loss = 69.62916, step = 9003 (30.835 sec)
# INFO:tensorflow:nll_loss = 60.31749, kl_w = 0.9999547, kl_loss = 9.31209 (30.835 sec)
# INFO:tensorflow:global_step/sec: 3.33689
# INFO:tensorflow:loss = 68.108185, step = 9103 (29.968 sec)
# INFO:tensorflow:nll_loss = 58.877937, kl_w = 0.99996173, kl_loss = 9.2306 (29.968 sec)
# INFO:tensorflow:global_step/sec: 3.33668
# INFO:tensorflow:loss = 67.86802, step = 9203 (29.970 sec)
# INFO:tensorflow:nll_loss = 58.36364, kl_w = 0.9999676, kl_loss = 9.504686 (29.970 sec)
# INFO:tensorflow:global_step/sec: 3.31123
# INFO:tensorflow:loss = 65.57287, step = 9303 (30.200 sec)
# INFO:tensorflow:nll_loss = 55.894623, kl_w = 0.9999726, kl_loss = 9.678508 (30.200 sec)
# INFO:tensorflow:Saving checkpoints for 9384 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:Loss for final step: 63.665504.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-9384
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have to admit that i thought it was a lot of the worst <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a lot of time to watch it if you are a <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-9384
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9385 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:loss = 69.25241, step = 9385
# INFO:tensorflow:nll_loss = 59.422077, kl_w = 0.99997604, kl_loss = 9.83057
# INFO:tensorflow:global_step/sec: 3.16585
# INFO:tensorflow:loss = 65.18898, step = 9485 (31.588 sec)
# INFO:tensorflow:nll_loss = 55.195877, kl_w = 0.99997973, kl_loss = 9.993306 (31.588 sec)
# INFO:tensorflow:global_step/sec: 3.18595
# INFO:tensorflow:loss = 64.00349, step = 9585 (31.388 sec)
# INFO:tensorflow:nll_loss = 54.068283, kl_w = 0.99998283, kl_loss = 9.935375 (31.388 sec)
# INFO:tensorflow:global_step/sec: 2.61602
# INFO:tensorflow:loss = 63.745422, step = 9685 (38.226 sec)
# INFO:tensorflow:nll_loss = 53.873295, kl_w = 0.99998546, kl_loss = 9.8722725 (38.226 sec)
# INFO:tensorflow:global_step/sec: 2.68683
# INFO:tensorflow:loss = 65.66029, step = 9785 (37.219 sec)
# INFO:tensorflow:nll_loss = 55.655636, kl_w = 0.9999877, kl_loss = 10.004782 (37.219 sec)
# INFO:tensorflow:global_step/sec: 2.83986
# INFO:tensorflow:loss = 70.41083, step = 9885 (35.213 sec)
# INFO:tensorflow:nll_loss = 60.81614, kl_w = 0.9999896, kl_loss = 9.594784 (35.213 sec)
# INFO:tensorflow:global_step/sec: 2.5178
# INFO:tensorflow:loss = 67.51283, step = 9985 (39.719 sec)
# INFO:tensorflow:nll_loss = 57.8248, kl_w = 0.9999912, kl_loss = 9.68812 (39.719 sec)
# INFO:tensorflow:global_step/sec: 2.60931
# INFO:tensorflow:loss = 67.748985, step = 10085 (38.323 sec)
# INFO:tensorflow:nll_loss = 58.29786, kl_w = 0.9999925, kl_loss = 9.451195 (38.323 sec)
# INFO:tensorflow:Saving checkpoints for 10166 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt.
# INFO:tensorflow:Loss for final step: 66.85924.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-10166
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this film because it was in the one of the best movies <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this one is a waste of time to watch it and don't watch it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp8tp0i2g/model.ckpt-10166
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
