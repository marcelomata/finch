# %% [markdown]
# <img src="img/charrnn.jpeg" width="500">

# %%
import tensorflow as tf
import numpy as np

# %%
params = {
    'batch_size': 128,
    'text_iter_step': 25,
    'seq_len': 200,
    'hidden_dim': 128,
    'n_layers': 2,
    'beam_width': 5,
    'display_step': 10,
    'generate_step': 100,
    'clip_norm': 5.0,
}

# %%
def parse_text(file_path):
    with open(file_path) as f:
        text = f.read()
    
    char2idx = {c: i+3 for i, c in enumerate(set(text))}
    char2idx['<pad>'] = 0
    char2idx['<start>'] = 1
    char2idx['<end>'] = 2
    
    ints = np.array([char2idx[char] for char in list(text)])
    return ints, char2idx

def next_batch(ints):
    len_win = params['seq_len'] * params['batch_size']
    for i in range(0, len(ints)-len_win, params['text_iter_step']):
        clip = ints[i: i+len_win]
        yield clip.reshape([params['batch_size'], params['seq_len']])
        
def input_fn(ints):
    dataset = tf.data.Dataset.from_generator(
        lambda: next_batch(ints), tf.int32, tf.TensorShape([None, params['seq_len']]))
    iterator = dataset.make_one_shot_iterator()
    return iterator.get_next()

# %%
def start_sent(x):
    _x = tf.fill([tf.shape(x)[0], 1], params['char2idx']['<start>'])
    return tf.concat([_x, x], 1)

def end_sent(x):
    _x = tf.fill([tf.shape(x)[0], 1], params['char2idx']['<end>'])
    return tf.concat([x, _x], 1)

def cell_fn():
    return tf.nn.rnn_cell.ResidualWrapper(
        tf.nn.rnn_cell.GRUCell(params['hidden_dim'],
            kernel_initializer=tf.orthogonal_initializer()))
  
def multi_cell_fn():
    return tf.nn.rnn_cell.MultiRNNCell([cell_fn() for _ in range(params['n_layers'])])

def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    return zip(clipped_grads, variables)

# %%
def forward(inputs, is_training):
    batch_sz = tf.shape(inputs)[0]
    
    if is_training:
        with tf.variable_scope('main', reuse=False):
            embedding = tf.get_variable('lookup_table', [params['vocab_size'], params['hidden_dim']])
            cells = multi_cell_fn()
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = tf.nn.embedding_lookup(embedding, inputs),
                sequence_length = tf.count_nonzero(inputs, 1, dtype=tf.int32))

            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = cells,
                helper = helper,
                initial_state = cells.zero_state(batch_sz, tf.float32),
                output_layer = tf.layers.Dense(params['vocab_size']))

            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder)

            logits = decoder_output.rnn_output
            return logits
    
    if not is_training:
        with tf.variable_scope('main', reuse=True):
            cells = multi_cell_fn()
            
            decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                cell = cells,
                embedding = tf.get_variable('lookup_table'),
                start_tokens = tf.tile(tf.constant(
                    [params['char2idx']['<start>']], dtype=tf.int32), [1]),
                end_token = params['char2idx']['<end>'],
                initial_state = tf.contrib.seq2seq.tile_batch(
                    cells.zero_state(1, tf.float32), params['beam_width']),
                beam_width = params['beam_width'],
                output_layer = tf.layers.Dense(params['vocab_size'], _reuse=True))

            decoder_out, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = params['seq_len'])

            predict = decoder_out.predicted_ids[:, :, 0]
            return predict

# %%
ints, params['char2idx'] = parse_text('../temp/anna.txt')
params['vocab_size'] = len(params['char2idx'])
params['idx2char'] = {i: c for c, i in params['char2idx'].items()}
print('Vocabulary size:', params['vocab_size'])

ops = {}
X = input_fn(ints)

logits = forward(start_sent(X), is_training=True)
ops['generate'] = forward(start_sent(X), is_training=False)

ops['global_step'] = tf.Variable(0, trainable=False)

targets = end_sent(X)
ops['loss'] = tf.reduce_mean(tf.contrib.seq2seq.sequence_loss(
    logits = logits,
    targets = targets,
    weights = tf.to_float(tf.ones_like(targets))))

ops['train'] = tf.train.AdamOptimizer().apply_gradients(
    clip_grads(ops['loss']), global_step=ops['global_step'])
# Out:
# Vocabulary size: 86

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
while True:
    try:
        sess.run(ops['train'])
    except tf.errors.OutOfRangeError:
        break
    else:
        step = sess.run(ops['global_step'])
        if step % params['display_step'] == 0 or step == 1:
            loss = sess.run(ops['loss'])
            print("Step %d | Loss %.3f" % (step, loss))
        if step % params['generate_step'] == 0 and step > 1:
            ints = sess.run(ops['generate'])[0]
            print('\n'+''.join([params['idx2char'][i] for i in ints])+'\n')
# Out:
# Step 1 | Loss 4.419
# Step 10 | Loss 3.546
# Step 20 | Loss 3.134
# Step 30 | Loss 3.018
# Step 40 | Loss 2.926
# Step 50 | Loss 2.798
# Step 60 | Loss 2.647
# Step 70 | Loss 2.532
# Step 80 | Loss 2.446
# Step 90 | Loss 2.379
# Step 100 | Loss 2.324
#
# the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Step 110 | Loss 2.273
# Step 120 | Loss 2.223
# Step 130 | Loss 2.172
# Step 140 | Loss 2.127
# Step 150 | Loss 2.083
# Step 160 | Loss 2.040
# Step 170 | Loss 1.993
# Step 180 | Loss 1.944
# Step 190 | Loss 1.899
# Step 200 | Loss 1.861
#
#  the said, and the could that the said, and the could that the said, and the could that the said, and the could that the said, and the could that the said, and the could that the said, and the could t
#
# Step 210 | Loss 1.823
# Step 220 | Loss 1.785
# Step 230 | Loss 1.745
# Step 240 | Loss 1.706
# Step 250 | Loss 1.670
# Step 260 | Loss 1.630
# Step 270 | Loss 1.596
# Step 280 | Loss 1.563
# Step 290 | Loss 1.525
# Step 300 | Loss 1.491
#
#  the could not the said, and that he said, and that he said, and that he said, and that he said, and that he said, and that he said, and that he said, and that he said, and that he said, and that she
#
# Step 310 | Loss 1.458
# Step 320 | Loss 1.421
# Step 330 | Loss 1.385
# Step 340 | Loss 1.351
# Step 350 | Loss 1.313
# Step 360 | Loss 1.280
# Step 370 | Loss 1.247
# Step 380 | Loss 1.215
# Step 390 | Loss 1.178
# Step 400 | Loss 1.144
#
#  the children, and conting to her face, that he had beation with his wife.
#
# "Well, what he said, was impossible to her face, that in the children, and could not the children, and conting to her face,
#
# Step 410 | Loss 1.108
# Step 420 | Loss 1.073
# Step 430 | Loss 1.041
# Step 440 | Loss 1.012
# Step 450 | Loss 0.971
# Step 460 | Loss 0.950
# Step 470 | Loss 0.905
# Step 480 | Loss 0.873
# Step 490 | Loss 0.842
# Step 500 | Loss 0.806
#
# ther things and the children, and could not go on like this hands with the door.
#
# Stepan Arkadyevitch could not go on like this hands with his wife. He was conscious that it was impossible to go away,
#
# Step 510 | Loss 0.775
# Step 520 | Loss 0.753
# Step 530 | Loss 0.717
# Step 540 | Loss 0.698
# Step 550 | Loss 0.667
# Step 560 | Loss 0.644
# Step 570 | Loss 0.617
# Step 580 | Loss 0.593
# Step 590 | Loss 0.574
# Step 600 | Loss 0.558
#
#  some little private room,
# put on his uniform, and went into the boardroom. The friends and by wheme, and the most important position. "He listened to the course of
# these three days, the youngest was
#
# Step 610 | Loss 0.533
# Step 620 | Loss 0.516
# Step 630 | Loss 0.500
# Step 640 | Loss 0.488
# Step 650 | Loss 0.485
# Step 660 | Loss 0.475
# Step 670 | Loss 0.461
# Step 680 | Loss 0.453
# Step 690 | Loss 0.436
# Step 700 | Loss 0.440
#
#  her father's and to
# which it was impossible to go away; but,
# cheating herself, she went on all the same sorting out her things and
# pretending she was going.
#
# Seeing her husband, she dropped her hands
#
# Step 710 | Loss 0.425
# Step 720 | Loss 0.424
# Step 730 | Loss 0.413
# Step 740 | Loss 0.411
# Step 750 | Loss 0.399
# Step 760 | Loss 0.397
# Step 770 | Loss 0.381
# Step 780 | Loss 0.389
# Step 790 | Loss 0.377
# Step 800 | Loss 0.374
#
# the thought. In a rapid she was conscious that this was
# impossible; it was impossible because she could not get out of the habit
# of regarding him as her husband and loving him. Besides this, she
# reali
#
# Step 810 | Loss 0.370
# Step 820 | Loss 0.363
# Step 830 | Loss 0.361
# Step 840 | Loss 0.363
# Step 850 | Loss 0.361
# Step 860 | Loss 0.377
# Step 870 | Loss 0.369
# Step 880 | Loss 0.360
# Step 890 | Loss 0.354
# Step 900 | Loss 0.348
#
#  something," he said, and dist into the board borgh the doorkeeper.
#
# "Someone, your excellency, crept in without pe<end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end>
#
# Step 910 | Loss 0.348
# Step 920 | Loss 0.359
# Step 930 | Loss 0.338
# Step 940 | Loss 0.357
# Step 950 | Loss 0.376
# Step 960 | Loss 0.364
# Step 970 | Loss 0.376
# Step 980 | Loss 0.375
# Step 990 | Loss 0.380
# Step 1000 | Loss 0.380
#
#  that they way, and drond that it was in the boardroom and went into his private <end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end><end>
#
# Step 1010 | Loss 0.359
# Step 1020 | Loss 0.376
# Step 1030 | Loss 0.374
# Step 1040 | Loss 0.377
# Step 1050 | Loss 0.378
# Step 1060 | Loss 0.384
# Step 1070 | Loss 0.391
# Step 1080 | Loss 0.395
# Step 1090 | Loss 0.379
# Step 1100 | Loss 0.390
#
#  the familyer, and a thish and her face the door.
#
# "Leting sightly a proper and the first pose before, and he took a glass of champagne, and he took a glass of champagne with
# everyone, and when in con
#
# Step 1110 | Loss 0.373
# Step 1120 | Loss 0.386
# Step 1130 | Loss 0.386
# Step 1140 | Loss 0.383
