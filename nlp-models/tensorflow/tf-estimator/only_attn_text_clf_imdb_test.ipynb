# %% [markdown]
# Author: [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="img/self_attn.png" width="300">

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report

# %%
VOCAB_SIZE = 5000
MAX_LEN = 500
HIDDEN_DIM = 50
BATCH_SIZE = 32
LR = {'start': 5e-3, 'end': 5e-4, 'steps': 1500}
N_EPOCH = 2
N_CLASS = 2

# %%
def embed_seq(x, vocab_sz, embed_dim, name):
    embedding = tf.get_variable(name, [vocab_sz, embed_dim])
    return tf.nn.embedding_lookup(embedding, x)


def position_embedding(inputs, repr_dim=HIDDEN_DIM):
    T = inputs.get_shape().as_list()[1]
    x = tf.range(T)                            # (T)
    x = tf.expand_dims(x, 0)                   # (1, T)
    x = tf.tile(x, [tf.shape(inputs)[0], 1])   # (N, T)
    return embed_seq(x, T, repr_dim, 'position_embedding')


def google_position_encoding(inputs, repr_dim=HIDDEN_DIM):
    T = inputs.get_shape().as_list()[1]
    pos_idx = tf.tile(tf.expand_dims(tf.range(T), 0), [tf.shape(inputs)[0], 1])

    pos_enc = np.array(
        [[pos / np.power(10000, 2*i/repr_dim) for i in range(repr_dim)] for pos in range(T)])
    pos_enc[:, 0::2] = np.sin(pos_enc[:, 0::2])  
    pos_enc[:, 1::2] = np.cos(pos_enc[:, 1::2]) 

    lookup_table = tf.convert_to_tensor(pos_enc, tf.float32)
    return tf.nn.embedding_lookup(lookup_table, pos_idx)


def importance_weighting(inputs):
    x = tf.layers.conv1d(inputs,
                         filters = HIDDEN_DIM//2,
                         kernel_size = 1,
                         activation = tf.tanh)
    x = tf.layers.conv1d(x,
                         filters = 1,
                         kernel_size = 1)
    return tf.squeeze(x, -1)


def forward(inputs, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    
    x = embed_seq(inputs, VOCAB_SIZE, HIDDEN_DIM, 'word_embedding')
    
    # alignment
    align = importance_weighting(x)
    # masking
    masks = tf.sign(inputs)
    paddings = tf.fill(tf.shape(align), float('-inf'))
    align = tf.where(tf.equal(masks, 0), paddings, align)
    # probability
    align = tf.expand_dims(tf.nn.softmax(align), -1)
    align = tf.layers.dropout(align, 0.1, training=is_training)
    # weighted sum
    x = tf.squeeze(tf.matmul(tf.transpose(x, [0,2,1]), align), -1)

    logits = tf.layers.dense(x, N_CLASS)
    return logits


def model_fn(features, labels, mode):
    logits = forward(features, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        preds = tf.argmax(logits, -1)
        return tf.estimator.EstimatorSpec(mode, predictions=preds)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_global_step()

        lr_op = tf.train.exponential_decay(
            LR['start'], global_step, LR['steps'], LR['end']/LR['start'])

        loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits=logits, labels=labels))

        train_op = tf.train.AdamOptimizer(lr_op).minimize(
            loss_op, global_step=global_step)

        lth = tf.train.LoggingTensorHook({'lr': lr_op}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=VOCAB_SIZE)
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, MAX_LEN, padding='post')
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, MAX_LEN, padding='post')

estimator = tf.estimator.Estimator(model_fn)

for _ in range(N_EPOCH):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = X_train, y = y_train,
        batch_size = BATCH_SIZE,
        shuffle = True))
    y_pred = np.fromiter(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = X_test,
        batch_size = BATCH_SIZE,
        shuffle = False)), np.int32)
    print("\nValidation Accuracy: %.4f\n" % (y_pred==y_test).mean())
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12097b828>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli/model.ckpt.
# INFO:tensorflow:loss = 0.6934027, step = 1
# INFO:tensorflow:lr = 0.005
# INFO:tensorflow:global_step/sec: 57.5442
# INFO:tensorflow:loss = 0.28155583, step = 101 (1.739 sec)
# INFO:tensorflow:lr = 0.004288479 (1.739 sec)
# INFO:tensorflow:global_step/sec: 60.8981
# INFO:tensorflow:loss = 0.2563052, step = 201 (1.642 sec)
# INFO:tensorflow:lr = 0.0036782112 (1.642 sec)
# INFO:tensorflow:global_step/sec: 60.149
# INFO:tensorflow:loss = 0.2604271, step = 301 (1.663 sec)
# INFO:tensorflow:lr = 0.0031547868 (1.663 sec)
# INFO:tensorflow:global_step/sec: 58.3419
# INFO:tensorflow:loss = 0.2291218, step = 401 (1.714 sec)
# INFO:tensorflow:lr = 0.0027058476 (1.714 sec)
# INFO:tensorflow:global_step/sec: 59.1535
# INFO:tensorflow:loss = 0.26192954, step = 501 (1.691 sec)
# INFO:tensorflow:lr = 0.0023207942 (1.690 sec)
# INFO:tensorflow:global_step/sec: 58.9427
# INFO:tensorflow:loss = 0.17904586, step = 601 (1.696 sec)
# INFO:tensorflow:lr = 0.0019905358 (1.697 sec)
# INFO:tensorflow:global_step/sec: 58.2306
# INFO:tensorflow:loss = 0.4743725, step = 701 (1.717 sec)
# INFO:tensorflow:lr = 0.0017072745 (1.717 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16534567.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8884
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli/model.ckpt.
# INFO:tensorflow:loss = 0.2459105, step = 783
# INFO:tensorflow:lr = 0.0015053472
# INFO:tensorflow:global_step/sec: 58.1683
# INFO:tensorflow:loss = 0.3020514, step = 883 (1.720 sec)
# INFO:tensorflow:lr = 0.00129113 (1.720 sec)
# INFO:tensorflow:global_step/sec: 59.3182
# INFO:tensorflow:loss = 0.20632817, step = 983 (1.686 sec)
# INFO:tensorflow:lr = 0.001107397 (1.686 sec)
# INFO:tensorflow:global_step/sec: 56.2236
# INFO:tensorflow:loss = 0.1391423, step = 1083 (1.778 sec)
# INFO:tensorflow:lr = 0.00094980985 (1.778 sec)
# INFO:tensorflow:global_step/sec: 57.9895
# INFO:tensorflow:loss = 0.26596072, step = 1183 (1.725 sec)
# INFO:tensorflow:lr = 0.00081464805 (1.725 sec)
# INFO:tensorflow:global_step/sec: 60.3967
# INFO:tensorflow:loss = 0.1463219, step = 1283 (1.656 sec)
# INFO:tensorflow:lr = 0.0006987203 (1.655 sec)
# INFO:tensorflow:global_step/sec: 59.9297
# INFO:tensorflow:loss = 0.1520106, step = 1383 (1.669 sec)
# INFO:tensorflow:lr = 0.00059928955 (1.669 sec)
# INFO:tensorflow:global_step/sec: 60.7782
# INFO:tensorflow:loss = 0.23374018, step = 1483 (1.645 sec)
# INFO:tensorflow:lr = 0.00051400816 (1.645 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.05873721.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpdbcaflli/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8886
